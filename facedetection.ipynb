# %%
#face detection
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
import cv2
import numpy as np
import dlib
import cv2
from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt

# %%
import urllib
import urllib.request

url, filename = ("https://www.homelight.com/blog/wp-content/uploads/2019/04/can-i-sell-my-house-to-a-family-member.png", "faces.png")
try: 
  urllib.URLopener().retrieve(url, filename)
except: 
  urllib.request.urlretrieve(url, filename)

from PIL import Image
from torchvision import transforms
input_image = Image.open(filename)

# %%
# show the photo

import matplotlib.pyplot as plt
plt.imshow(input_image)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Read the input image
img = cv2.imread('faces.png')

grayImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(grayImage)
print (type(faces))
print (faces)
# Out:
# <class 'numpy.ndarray'>
# [[843 201  61  61]
#  [759 213  63  63]
#  [701 426  27  27]
#  [721 378  59  59]
#  [846 342  62  62]
#  [ 53 372  64  64]]

# %%
faces.shape[0]
# Out:
# 6

# %%
faces = face_cascade.detectMultiScale(grayImage)
print ("Number of faces detected: " + str(faces.shape[0]))
# Out:
# Number of faces detected: 6

# %%
# Detect faces
faces = face_cascade.detectMultiScale(grayImage, 1.1, 4)

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Display the output
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x800 at 0x7FDDAE8ED1D0>

# %%
print ("Number of faces detected: " + str(faces.shape[0]))
# Out:
# Number of faces detected: 4
